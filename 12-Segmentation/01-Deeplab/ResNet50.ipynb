# %%
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model

# %%
weights_path = './resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5'
base_model = keras.applications.ResNet50(weights=weights_path, include_top=False, input_shape=(256,256,3))

# %%
base_model.summary()

# %%
# conv{stage}_block{block_number}_{layer_number}_{type}

# %%
keras.utils.plot_model(base_model,show_layer_names=True)
